# %%
# improve speed of SVC in sklearn
from sklearnex import patch_sklearn
patch_sklearn("SVC")
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import sys
sys.path.insert(0, '..')

# %%
from machine_learning.ml_detector import DetectorML
from metrics.metrics_utils import get_tp_fp_fn_center_patch_criteria

# %%
import pandas as pd
import numpy as np

from database.dataset import *

# set the seed for reproducible execution
rseed = np.random.seed(42)

# %%
det_ml = DetectorML('/home/vzalevskyi/projects/data/cascade/cascade_models.pkl')
# Out:
# Loading model...
# Selected sensitivity threshold to keep 0.98
# Confidence threshold to keep given sensitivity is 0.00380
# Filtering out all candidates with confidence <=0.00380 is estimated to reduce FP by 49.97 %

# %% [markdown]
# # Validation

# %%
db = INBreast_Dataset(
    return_lesions_mask=True,
    level='image',
    max_lesion_diam_mm=None,
    extract_patches=False,
    partitions=['validation'],
    lesion_types=['calcification', 'cluster'],
    cropped_imgs=True,
    keep_just_images_of_lesion_type=False,
    use_muscle_mask=False,
    ignore_diameter_px=15
)

# %% [markdown]
# Circular metric

# %%
all_features = []
all_tps = []
all_fps = []
all_fns = []
all_ignored_candidates = []
save_path = Path.cwd().parent.parent/'data/test_features/val/circular'
for idx in tqdm(range(len(db))):
    # extracting data
    db_sample = db[idx]
    image = db_sample['img']
    image_id = db.df.iloc[idx].img_id
    image_mask = db_sample['lesion_mask']

    cand_features_probas = det_ml.detect(image)
    cand_features_probas['img_id'] = image_id
    
    tp, fp, fn, ignored_candidates = get_tp_fp_fn_center_patch_criteria(
        np.stack(cand_features_probas.candidate_coordinates.values).astype(int), image_mask, None, 14, True)
    tp['img_id'] = image_id
    fp['img_id'] = image_id
    fn['img_id'] = image_id
    ignored_candidates['img_id'] = image_id
    
    all_features.append(cand_features_probas)
    all_tps.append(tp)
    all_fps.append(fp)
    all_fns.append(fn)
    all_ignored_candidates.append(ignored_candidates)
    

all_features = pd.DataFrame(all_features)
all_tps = pd.DataFrame(all_tps)
all_fps = pd.DataFrame(all_fps)
all_fns = pd.DataFrame(all_fns)
all_ignored_candidates = pd.DataFrame(all_ignored_candidates)
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   2%|▏         | 1/62 [00:40<41:22, 40.69s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   3%|▎         | 2/62 [01:15<37:25, 37.42s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   5%|▍         | 3/62 [02:01<40:28, 41.16s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   6%|▋         | 4/62 [02:57<45:22, 46.94s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   8%|▊         | 5/62 [03:41<43:43, 46.02s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  10%|▉         | 6/62 [04:10<37:38, 40.34s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  11%|█▏        | 7/62 [04:54<37:54, 41.36s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  13%|█▎        | 8/62 [05:47<40:39, 45.18s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  15%|█▍        | 9/62 [06:13<34:35, 39.16s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  16%|█▌        | 10/62 [06:39<30:21, 35.03s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  18%|█▊        | 11/62 [07:22<31:53, 37.51s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  19%|█▉        | 12/62 [07:59<30:59, 37.19s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  21%|██        | 13/62 [09:19<41:08, 50.37s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  23%|██▎       | 14/62 [10:25<44:01, 55.04s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  24%|██▍       | 15/62 [11:58<52:05, 66.51s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  26%|██▌       | 16/62 [13:17<53:45, 70.11s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  27%|██▋       | 17/62 [14:21<51:22, 68.49s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  29%|██▉       | 18/62 [15:25<49:07, 66.99s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  31%|███       | 19/62 [16:32<48:03, 67.05s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  32%|███▏      | 20/62 [17:40<47:09, 67.37s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  34%|███▍      | 21/62 [18:12<38:46, 56.75s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  35%|███▌      | 22/62 [18:50<33:58, 50.96s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  37%|███▋      | 23/62 [19:13<27:45, 42.71s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  39%|███▊      | 24/62 [19:37<23:32, 37.17s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  40%|████      | 25/62 [20:00<20:18, 32.94s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  42%|████▏     | 26/62 [20:13<16:09, 26.92s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  44%|████▎     | 27/62 [20:55<18:22, 31.50s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  45%|████▌     | 28/62 [21:38<19:45, 34.86s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  47%|████▋     | 29/62 [22:10<18:38, 33.88s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  48%|████▊     | 30/62 [22:37<17:04, 32.01s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  50%|█████     | 31/62 [23:18<17:48, 34.46s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  52%|█████▏    | 32/62 [24:12<20:14, 40.47s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  53%|█████▎    | 33/62 [25:17<23:02, 47.68s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  55%|█████▍    | 34/62 [25:50<20:12, 43.29s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  56%|█████▋    | 35/62 [26:39<20:22, 45.26s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  58%|█████▊    | 36/62 [27:08<17:24, 40.18s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  60%|█████▉    | 37/62 [27:22<13:33, 32.53s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  61%|██████▏   | 38/62 [27:55<12:59, 32.50s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  63%|██████▎   | 39/62 [28:20<11:37, 30.33s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  65%|██████▍   | 40/62 [28:51<11:08, 30.39s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  66%|██████▌   | 41/62 [29:22<10:40, 30.51s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  68%|██████▊   | 42/62 [29:43<09:18, 27.93s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  69%|██████▉   | 43/62 [30:05<08:15, 26.10s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  71%|███████   | 44/62 [30:28<07:30, 25.00s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  73%|███████▎  | 45/62 [31:36<10:45, 37.94s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  74%|███████▍  | 46/62 [33:07<14:23, 53.97s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  76%|███████▌  | 47/62 [34:12<14:16, 57.08s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  77%|███████▋  | 48/62 [35:21<14:09, 60.64s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  79%|███████▉  | 49/62 [35:57<11:35, 53.52s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  81%|████████  | 50/62 [36:46<10:24, 52.03s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  82%|████████▏ | 51/62 [37:14<08:12, 44.76s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  84%|████████▍ | 52/62 [37:41<06:34, 39.43s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  85%|████████▌ | 53/62 [38:27<06:13, 41.55s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  87%|████████▋ | 54/62 [39:16<05:49, 43.70s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  89%|████████▊ | 55/62 [40:27<06:03, 51.90s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  90%|█████████ | 56/62 [41:36<05:42, 57.11s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  92%|█████████▏| 57/62 [42:20<04:26, 53.23s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  94%|█████████▎| 58/62 [43:00<03:16, 49.15s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  95%|█████████▌| 59/62 [43:52<02:29, 49.84s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  97%|█████████▋| 60/62 [44:45<01:42, 51.04s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  98%|█████████▊| 61/62 [45:37<00:51, 51.28s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
# 100%|██████████| 62/62 [46:37<00:00, 45.13s/it]
# /home/vzalevskyi/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:540: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
all_features = pd.concat(all_features[0].values)
all_tps = pd.concat(all_tps[0].values)
all_fps = pd.concat(all_fps[0].values)
all_fns = pd.concat(all_fns[0].values)
all_ignored_candidates = pd.concat(all_ignored_candidates[0].values)

# %%
all_features.reset_index().to_feather(str(save_path) + 'features.f')
all_tps.reset_index().to_feather(str(save_path) + 'tps.f')
all_fps.reset_index().to_feather(str(save_path) + 'fps.f')
all_fns.reset_index().to_feather(str(save_path) + 'fns.f')
all_ignored_candidates.reset_index().to_feather(str(save_path) + 'ignored_candidates.f')

# %% [markdown]
# Square

# %%
all_features = []
all_tps = []
all_fps = []
all_fns = []
all_ignored_candidates = []
save_path = Path.cwd().parent.parent/'data/test_features/val/square'
for idx in tqdm(range(len(db))):
    # extracting data
    db_sample = db[idx]
    image = db_sample['img']
    image_id = db.df.iloc[idx].img_id
    image_mask = db_sample['lesion_mask']

    cand_features_probas = det_ml.detect(image)
    cand_features_probas['img_id'] = image_id
    
    tp, fp, fn, ignored_candidates = get_tp_fp_fn_center_patch_criteria(
        np.stack(cand_features_probas.candidate_coordinates.values).astype(int), image_mask, None, 14, False)
    tp['img_id'] = image_id
    fp['img_id'] = image_id
    fn['img_id'] = image_id
    ignored_candidates['img_id'] = image_id
    
    all_features.append(cand_features_probas)
    all_tps.append(tp)
    all_fps.append(fp)
    all_fns.append(fn)
    all_ignored_candidates.append(ignored_candidates)
    

all_features = pd.concat(all_features).reset_index()
all_tps = pd.concat(all_tps).reset_index()
all_fps = pd.concat(all_fps).reset_index()
all_fns = pd.concat(all_fns).reset_index()
all_ignored_candidates = pd.concat(all_ignored_candidates).reset_index()

all_features.to_feather(str(save_path) + 'features.f')
all_tps.to_feather(str(save_path) + 'tps.f')
all_fps.to_feather(str(save_path) + 'fps.f')
all_fns.to_feather(str(save_path) + 'fns.f')
all_ignored_candidates.to_feather(str(save_path) + 'ignored_candidates.f')
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   2%|▏         | 1/62 [00:42<43:24, 42.69s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   3%|▎         | 2/62 [01:20<39:46, 39.78s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   5%|▍         | 3/62 [02:03<40:29, 41.17s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   6%|▋         | 4/62 [02:56<44:31, 46.06s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#   8%|▊         | 5/62 [03:41<43:14, 45.52s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  10%|▉         | 6/62 [04:13<38:14, 40.98s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  11%|█▏        | 7/62 [05:00<39:12, 42.78s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  13%|█▎        | 8/62 [05:54<41:59, 46.66s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  15%|█▍        | 9/62 [06:23<36:19, 41.12s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  16%|█▌        | 10/62 [06:51<31:56, 36.85s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  18%|█▊        | 11/62 [07:35<33:10, 39.03s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  19%|█▉        | 12/62 [08:13<32:21, 38.82s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  21%|██        | 13/62 [09:41<43:49, 53.66s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  23%|██▎       | 14/62 [10:50<46:43, 58.40s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  24%|██▍       | 15/62 [12:55<1:01:19, 78.29s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  26%|██▌       | 16/62 [14:18<1:01:13, 79.86s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  27%|██▋       | 17/62 [15:26<57:10, 76.23s/it]  INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  29%|██▉       | 18/62 [16:35<54:25, 74.22s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  31%|███       | 19/62 [17:47<52:35, 73.38s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  32%|███▏      | 20/62 [18:56<50:33, 72.22s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  34%|███▍      | 21/62 [19:31<41:32, 60.80s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  35%|███▌      | 22/62 [20:10<36:16, 54.42s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  37%|███▋      | 23/62 [20:34<29:24, 45.24s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  39%|███▊      | 24/62 [20:57<24:23, 38.51s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  40%|████      | 25/62 [21:20<20:52, 33.86s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  42%|████▏     | 26/62 [21:33<16:33, 27.60s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  44%|████▎     | 27/62 [22:19<19:20, 33.16s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  45%|████▌     | 28/62 [23:04<20:45, 36.64s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  47%|████▋     | 29/62 [23:39<19:58, 36.30s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  48%|████▊     | 30/62 [24:08<18:12, 34.14s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  50%|█████     | 31/62 [24:51<18:55, 36.64s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  52%|█████▏    | 32/62 [25:49<21:37, 43.24s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  53%|█████▎    | 33/62 [27:00<24:48, 51.33s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  55%|█████▍    | 34/62 [27:36<21:53, 46.90s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  56%|█████▋    | 35/62 [28:29<21:55, 48.74s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  58%|█████▊    | 36/62 [28:57<18:25, 42.51s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  60%|█████▉    | 37/62 [29:12<14:18, 34.33s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  61%|██████▏   | 38/62 [29:43<13:19, 33.29s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  63%|██████▎   | 39/62 [30:10<12:03, 31.44s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  65%|██████▍   | 40/62 [30:37<10:59, 30.00s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  66%|██████▌   | 41/62 [31:00<09:45, 27.86s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  68%|██████▊   | 42/62 [31:24<08:55, 26.76s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  69%|██████▉   | 43/62 [31:47<08:06, 25.61s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  71%|███████   | 44/62 [32:08<07:14, 24.16s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  73%|███████▎  | 45/62 [33:10<10:05, 35.62s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  74%|███████▍  | 46/62 [34:29<12:57, 48.60s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  76%|███████▌  | 47/62 [35:24<12:36, 50.40s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  77%|███████▋  | 48/62 [36:25<12:32, 53.73s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  79%|███████▉  | 49/62 [37:05<10:44, 49.54s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  81%|████████  | 50/62 [37:51<09:41, 48.48s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  82%|████████▏ | 51/62 [38:17<07:40, 41.86s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  84%|████████▍ | 52/62 [38:42<06:06, 36.67s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  85%|████████▌ | 53/62 [39:26<05:50, 38.94s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  87%|████████▋ | 54/62 [40:06<05:13, 39.20s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  89%|████████▊ | 55/62 [41:08<05:22, 46.04s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  90%|█████████ | 56/62 [42:14<05:12, 52.10s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  92%|█████████▏| 57/62 [42:54<04:01, 48.30s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  94%|█████████▎| 58/62 [43:32<03:01, 45.39s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  95%|█████████▌| 59/62 [44:26<02:24, 48.05s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  97%|█████████▋| 60/62 [45:23<01:41, 50.64s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#  98%|█████████▊| 61/62 [46:16<00:51, 51.28s/it]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
# 100%|██████████| 62/62 [47:05<00:00, 45.57s/it]

# %% [markdown]
# # Test

# %%
db = INBreast_Dataset(
    return_lesions_mask=True,
    level='image',
    max_lesion_diam_mm=None,
    extract_patches=False,
    partitions=['test'],
    lesion_types=['calcification', 'cluster'],
    cropped_imgs=True,
    keep_just_images_of_lesion_type=False,
    use_muscle_mask=False,
    ignore_diameter_px=15
)

# %% [markdown]
# Circular metric

# %%
all_features = []
all_tps = []
all_fps = []
all_fns = []
all_ignored_candidates = []
save_path = Path.cwd().parent.parent/'data/test_features/test/circular'
for idx in tqdm(range(len(db))):
    # extracting data
    db_sample = db[idx]
    image = db_sample['img']
    image_id = db.df.iloc[idx].img_id
    image_mask = db_sample['lesion_mask']

    cand_features_probas = det_ml.detect(image)
    cand_features_probas['img_id'] = image_id
    
    tp, fp, fn, ignored_candidates = get_tp_fp_fn_center_patch_criteria(
        np.stack(cand_features_probas.candidate_coordinates.values).astype(int), image_mask, None, 14, True)
    tp['img_id'] = image_id
    fp['img_id'] = image_id
    fn['img_id'] = image_id
    ignored_candidates['img_id'] = image_id
    
    all_features.append(cand_features_probas)
    all_tps.append(tp)
    all_fps.append(fp)
    all_fns.append(fn)
    all_ignored_candidates.append(ignored_candidates)
    

all_features = pd.concat(all_features).reset_index()
all_tps = pd.concat(all_tps).reset_index()
all_fps = pd.concat(all_fps).reset_index()
all_fns = pd.concat(all_fns).reset_index()
all_ignored_candidates = pd.concat(all_ignored_candidates).reset_index()

all_features.to_feather(str(save_path) + 'features.f')
all_tps.to_feather(str(save_path) + 'tps.f')
all_fps.to_feather(str(save_path) + 'fps.f')
all_fns.to_feather(str(save_path) + 'fns.f')
all_ignored_candidates.to_feather(str(save_path) + 'ignored_candidates.f')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#