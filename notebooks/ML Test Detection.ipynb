# %%
# improve speed of SVC in sklearn
# might not be supported by some hardware
# if causes errors - ignore
# from sklearnex import patch_sklearn
# patch_sklearn("SVC")

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd

from database.dataset import *
from machine_learning.ml_detector import DetectorML
from general_utils.plots import simple_im_show, plot_candidates_rois

# %% [markdown]
# Initialize the database class, used for loading images and metadata

# %%
db = INBreast_Dataset(
    return_lesions_mask=True,
    level='image',
    max_lesion_diam_mm=None,
    extract_patches=False,
    partitions=['test'],
    lesion_types=['calcification', 'cluster'],
    cropped_imgs=True,
    keep_just_images_of_lesion_type=False,
    use_muscle_mask=False,
    ignore_diameter_px=15
)

# %% [markdown]
# Initilize an instance of the detection class used to perform detection

# %% [markdown]
# Provide below a path to the pickle file with the model. The file can be downloaded from this [link](https://drive.google.com/file/d/1DQfv8IGn8HJRgev6FCXdAQyHcb2HxxGY/view)

# %%
det_ml = DetectorML('/home/vzalevskyi/projects/data/cascade/cascade_models.pkl')
# Out:
# Loading model...
# /home/vzalevskyi/anaconda3/envs/calc_det/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator MinMaxScaler from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/vzalevskyi/projects/calc-det/notebooks/ML Test Detection.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/vzalevskyi/projects/calc-det/notebooks/ML%20Test%20Detection.ipynb#ch0000006?line=0'>1</a> det_ml = DetectorML('/home/vzalevskyi/projects/data/cascade/cascade_models.pkl')
#
# File ~/projects/calc-det/notebooks/../machine_learning/ml_detector.py:22, in DetectorML.__init__(self, cascade_model_path)
#      20 self.detector = MorphologyCalcificationDetection(**GSM_DEFAULT_PARAMS)
#      21 self.feature_extractor = CandidatesFeatureExtraction_MP()
# ---> 22 self.classifier = CascadeClassifier(cascade_model_path)
#
# File ~/projects/calc-det/notebooks/../machine_learning/cascade_classifier.py:27, in CascadeClassifier.__init__(self, models_path)
#      25 if self.models_path.exists():
#      26     print('Loading model...')
# ---> 27     self.load_models()
#      28 else:
#      29     print('Model not found. Need to call fit before predict.')
#
# File ~/projects/calc-det/notebooks/../machine_learning/cascade_classifier.py:175, in CascadeClassifier.load_models(self)
#     173 """Loads cascade models from pickle at models_path"""
#     174 with open(self.models_path, 'rb') as f:
# --> 175     c1m, c2m, tpr, thrs, labels, probas, keep_sens_thr = pickle.load(f)
#     177 self.sens_threshold = keep_sens_thr
#     178 self.first_model = c1m
#
# ModuleNotFoundError: No module named '_onedal4py_host'

# %% [markdown]
# Test the detector on the first image from the test set of the database (which was never used for any of the training/tuning processes)

# %%
img_idx = 42

image = db[img_idx]['img']
mask = db[img_idx]['lesion_mask']

candidates = det_ml.detect(image)
candidates
# Out:
# INFO:root:sklearn.svm.SVC._predict_proba: running accelerated version on CPU
# INFO:root:sklearn.svm.SVC.decision_function: running accelerated version on CPU
#      candidate_coordinates           patch_coordinates  confidence
# 0             [2, 3036, 1]     ((3029, 3043), (0, 14))    0.013468
# 1           [527, 2959, 0]  ((2952, 2966), (520, 534))    0.003180
# 2           [534, 2955, 1]  ((2948, 2962), (527, 541))    0.001036
# 3           [551, 2949, 0]  ((2942, 2956), (544, 558))    0.003063
# 4           [509, 2938, 0]  ((2931, 2945), (502, 516))    0.002747
# ...                    ...                         ...         ...
# 1537           [438, 2, 1]       ((0, 14), (431, 445))    0.001401
# 1538           [178, 1, 0]       ((0, 14), (171, 185))    0.000392
# 1539           [707, 0, 0]       ((0, 14), (700, 714))    0.002155
# 1540           [185, 0, 0]       ((0, 14), (178, 192))    0.001257
# 1541           [134, 1, 1]       ((0, 14), (127, 141))    0.000804
#
# [1542 rows x 3 columns]

# %% [markdown]
# Label candidates

# %%
candidates
# Out:
#      candidate_coordinates           patch_coordinates  confidence
# 0             [2, 3036, 1]     ((3029, 3043), (0, 14))    0.013468
# 1           [527, 2959, 0]  ((2952, 2966), (520, 534))    0.003180
# 2           [534, 2955, 1]  ((2948, 2962), (527, 541))    0.001036
# 3           [551, 2949, 0]  ((2942, 2956), (544, 558))    0.003063
# 4           [509, 2938, 0]  ((2931, 2945), (502, 516))    0.002747
# ...                    ...                         ...         ...
# 1537           [438, 2, 1]       ((0, 14), (431, 445))    0.001401
# 1538           [178, 1, 0]       ((0, 14), (171, 185))    0.000392
# 1539           [707, 0, 0]       ((0, 14), (700, 714))    0.002155
# 1540           [185, 0, 0]       ((0, 14), (178, 192))    0.001257
# 1541           [134, 1, 1]       ((0, 14), (127, 141))    0.000804
#
# [1542 rows x 3 columns]

# %%
result_image = plot_candidates_rois(image, mask, candidates, 0.5, k=0)
simple_im_show(cv2.cvtColor(result_image,  cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite('t2.png',result_image)
# Out:
# True
